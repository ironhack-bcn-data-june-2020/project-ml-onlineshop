# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/df_0_oh.csv")

# %%
df
# Out:
#        Unnamed: 0  Administrative  Administrative_Duration  Informational  \
# 0               0             0.0                 0.000294            0.0
# 1               1             0.0                 0.000294            0.0
# 2               2             0.0                 0.000000            0.0
# 3               3             0.0                 0.000294            0.0
# 4               4             0.0                 0.000294            0.0
# ...           ...             ...                      ...            ...
# 12299       12299            24.0                 0.000294            1.0
# 12300       12300            24.0                 0.000294            6.0
# 12301       12301            24.0                 0.000294            6.0
# 12302       12302            26.0                 0.000294            9.0
# 12303       12303            27.0                 0.000294            2.0
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# ...

# %%
sns.barplot(data=df, x='Weekend', y='Revenue')
_ = plt.title('Revenue by Week period')

# %%
sns.barplot(data=df, x='Month', y='Revenue')
_ = plt.title('Revenue by Month')
